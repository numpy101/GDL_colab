# %% [markdown]
# # 生成 Deep Learning
#
# - Google Drive にマウント
# - Google Drive に GDL_code をダウンロード (git clone)
#   - 初回だけ必要ですが2回目以降は不要です
#   - ダウンロードがすんだらコメントアウト
# - カレントディレクトリを変更
#   - GDL_code 配下に移動
# - 必要なライブラリをインストール
#   - pip install -r requirements.txt
# - ライブラリインストール後に、カーネル再起動

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/davidADSP/GDL_code.git
# Out:
# fatal: destination path 'GDL_code' already exists and is not an empty directory.

# %%
# %cd GDL_code/
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/GDL_code

# %%
# !pip install -r requirements.txt
# !pip install tensorflow-gpu==1.14.0
# Out:
# ...
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-ptwqxf_c
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-ptwqxf_c
# ...
#      |████████████████████████████████| 102kB 7.8MB/s
# ...
#      |████████████████████████████████| 163kB 17.7MB/s
# ...
#      |████████████████████████████████| 706kB 37.0MB/s
# ...
#      |████████████████████████████████| 10.6MB 21.9MB/s
# ...
#      |████████████████████████████████| 2.8MB 45.5MB/s
# ...
#      |████████████████████████████████| 122kB 61.0MB/s
# ...
#      |████████████████████████████████| 778kB 48.2MB/s
# ...
#      |████████████████████████████████| 112kB 66.0MB/s
# ...
#      |████████████████████████████████| 184kB 63.7MB/s
# ...
#      |████████████████████████████████| 133kB 65.2MB/s
# ...
#      |████████████████████████████████| 92kB 14.6MB/s
# ...
#      |████████████████████████████████| 133kB 65.6MB/s
# ...
#      |████████████████████████████████| 317kB 54.2MB/s
# ...

# %% [markdown]
# # 02

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/GDL_code
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/GDL_code

# %% [markdown]
# ## 02-01

# %%
# %run 02_01_deep_learning_deep_neural_network.ipynb
# Out:
# ...
# 170500096/170498071 [==============================] - 7s 0us/step
# W1119 03:07:39.499032 139767085913984 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               614600
# _________________________________________________________________
# ...

# %% [markdown]
# ## 02-02

# %%
# %run 02_02_deep_learning_convolutions.ipynb
# Out:
# (64, 64)
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %% [markdown]
# ## 02-03

# %%
# %run 02_03_deep_learning_conv_neural_network.ipynb
# Out:
# W1119 03:09:45.129430 139767085913984 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 10)        490
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 20)          1820
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                12810
# ...
# Total params: 15,120
# ...

# %% [markdown]
# # 03

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/GDL_code
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/GDL_code

# %% [markdown]
# ## 03-01

# %%
# %run 03_01_autoencoder_train.ipynb
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W1118 18:36:26.574386 140597050079104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1118 18:36:26.593237 140597050079104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1118 18:36:26.613765 140597050079104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...

# %% [markdown]
# ## 03-02

# %%
# %run 03_02_autoencoder_analysis.ipynb

# %% [markdown]
# ## 03-03

# %%
# %run 03_03_vae_digits_train.ipynb
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# encoder_input (InputLayer)      (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# encoder_conv_0 (Conv2D)         (None, 28, 28, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 28, 28, 32)   0           encoder_conv_0[0][0]
# __________________________________________________________________________________________________
# encoder_conv_1 (Conv2D)         (None, 14, 14, 64)   18496       leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 14, 14, 64)   0           encoder_conv_1[0][0]
# ...

# %% [markdown]
# ## 03-04

# %%
# %run 03_04_vae_digits_analysis.ipynb

# %% [markdown]
# ## 03-05

# %%
# %run 03_05_vae_faces_train.ipynb
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /content/gdrive/MyDrive/Colab Notebooks/GDL_code/03_05_vae_faces_train.ipynb in <module>
#       6                                          , shuffle = True
#       7                                          , class_mode = 'input'
# ----> 8                                          , subset = "training"
#       9                                             )
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     536             follow_links=follow_links,
#     537             subset=subset,
# --> 538             interpolation=interpolation
#     539         )
#     540
#
# ...

# %% [markdown]
# ## 03-06

# %%
# %run 03_06_vae_faces_analysis.ipynb
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /content/gdrive/My Drive/Colab Notebooks/GDL_code/03_06_vae_faces_analysis.ipynb in <module>
#       1 INPUT_DIM = (128,128,3)
#       2
# ----> 3 att = pd.read_csv(os.path.join(DATA_FOLDER, 'list_attr_celeba.csv'))
#       4
#       5 imageLoader = ImageLabelLoader(IMAGE_FOLDER, INPUT_DIM[:2])
#
# ...
